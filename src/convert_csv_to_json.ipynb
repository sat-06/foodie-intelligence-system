# %%
import pandas as pd

df = pd.read_csv('data/cleaned/final_food_orders.csv')

df.head()
# Out:
#    Resto_ID Resto_name   Subzone       City    Order_ID      Order_Placed_At  \
# 0  20320607      Swaad  Sector 4  Delhi NCR  6168884918  2024-09-10 23:38:00
# 1  20320607      Swaad  Sector 4  Delhi NCR  6170707559  2024-09-10 23:34:00
# 2  20320607      Swaad  Sector 4  Delhi NCR  6169375019  2024-09-10 15:52:00
# 3  20320607      Swaad  Sector 4  Delhi NCR  6151677434  2024-09-10 15:45:00
# 4  20320607      Swaad  Sector 4  Delhi NCR  6167540897  2024-09-10 15:04:00
#
#   Order_status         Delivery  Distance  \
# 0    Delivered  Zomato Delivery       3.0
# 1    Delivered  Zomato Delivery       2.0
# 2    Delivered  Zomato Delivery       NaN
# 3    Delivered  Zomato Delivery       2.0
# 4    Delivered  Zomato Delivery       2.0
#
#                                       Items_in_order  ... order_day_name  \
# 0  1 x Grilled Chicken Jamaican Tender, 1 x Grill...  ...        Tuesday
# 1  1 x Peri Peri Fries, 1 x Fried Chicken Angara ...  ...        Tuesday
# ...

# %%
import os

os.makedirs('frontend/src/data', exist_ok=True)

# %%
df.to_json(
    'frontend/src/data/finalFoodOrders.json',
    orient='records',
    indent=2
)

print("JSON file created successfully")
# Out:
# JSON file created successfully
