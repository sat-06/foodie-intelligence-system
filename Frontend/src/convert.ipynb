# %%
import pandas as pd

# %%
import os

# %%
import os

print(os.getcwd())
# Out:
# d:\foodie-intelligence-system\Frontend\src

# %%
import glob

glob.glob("**/final_food_orders.csv", recursive=True)
# Out:
# []

# %%
import pandas as pd
import os

df = pd.read_csv(r'D:/foodie-intelligence-system/src/data/cleaned/final_food_orders.csv')

os.makedirs(r'D:/foodie-intelligence-system/Frontend/src/data', exist_ok=True)

df.to_json(
    r'D:/foodie-intelligence-system/Frontend/src/data/finalFoodOrders.json',
    orient='records',
    indent=2
)

print("JSON created successfully")
# Out:
# JSON created successfully
